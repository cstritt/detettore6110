# %% [markdown]
# # Errors
#
# Executed cells are solved

# %% [markdown]
# Error with G31825:
#
# /scicore/home/gagneux/GROUP/tbresearch/genomes/IN_PROGRESS/common_mappings/PipelineTB/v2/G31/82/5/G31825.cram
#
# ```
# Traceback (most recent call last):
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/detettore6110.py", line 143, in <module>
#     main()
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/detettore6110.py", line 115, in main
#     read_d = readparsing.parse_paf(f'{temp_dir}/reads_vs_IS.paf')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/lib/readparsing.py", line 188, in parse_paf
#     read_d[read_id].add_coordinates(fields, boundary_margin)
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/lib/readparsing.py", line 61, in add_coordinates
#     anchor_start = min(list(not_mapping))
#                    ^^^^^^^^^^^^^^^^^^^^^^
# ValueError: min() iterable argument is empty
# ```

# %% [markdown]
# G00857
# /scicore/home/gagneux/GROUP/tbresearch/genomes/IN_PROGRESS/common_mappings/PipelineTB/v2/G00/85/7/G00857.cram
#
# ```
# Traceback (most recent call last):
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/detettore6110.py", line 147, in <module>
#     main()
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/detettore6110.py", line 120, in main
#     read_d = readparsing.parse_paf(f'{temp_dir}/reads_vs_IS.paf', args.min_anchor_len, args.min_hit_len)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/lib/readparsing.py", line 165, in parse_paf
#     paf = pandas.read_csv(paf_file, sep='\t', usecols=range(12), header=None)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/.snakemake/conda/5705a2711d0a6b99262920520ac6e1c8_/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/.snakemake/conda/5705a2711d0a6b99262920520ac6e1c8_/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/.snakemake/conda/5705a2711d0a6b99262920520ac6e1c8_/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/.snakemake/conda/5705a2711d0a6b99262920520ac6e1c8_/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1898, in _make_engine
#     return mapping[engine](f, **self.options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/.snakemake/conda/5705a2711d0a6b99262920520ac6e1c8_/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py", line 93, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "parsers.pyx", line 581, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# ```

# %% [markdown]
# G11513
# /scicore/home/gagneux/GROUP/tbresearch/genomes/IN_PROGRESS/common_mappings/PipelineTB/v2/G11/51/3/G11513.cram
#
# ```
# Traceback (most recent call last):
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/detettore6110.py", line 147, in <module>
#     main()
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/detettore6110.py", line 143, in main
#     io.write_reference_output(overlaps, cluster_d, args)
#   File "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/software/detettore6110/lib/io.py", line 245, in write_reference_output
#     support_5 = len(cluster_d['5'][five_cl_nr].reads)
#                     ~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 25
# ```

# %% [markdown]
# # Weird results
#
# Executed cells were solved

# %% [markdown]
# G36660
# /scicore/home/gagneux/GROUP/tbresearch/genomes/IN_PROGRESS/common_mappings/PipelineTB/v2/G36/66/0/G36660.cram
#
# CN of 41 in La2 strain...
#
# Strange pattern: relatively few reads, supposedly covering the whole IS. Poor anchor alignment outside the seed.
#
# Example: 5prime_3
#
# Check the reads from cluster 5prime_3 in the paf alignment
#
# => either some artefact, OR two insertions next to each other, separeted by a tsd??

# %%
from Bio import SeqIO

cluster = '5prime_14'

# read fasta
recs = SeqIO.parse(f"G36660_intermediate_files/{cluster}.aligned.fasta", "fasta")

reads_in_cluster = []

for rec in recs:
    read_id = rec.id.split('_')[0]
    reads_in_cluster.append(read_id)
    

with open('G36660_intermediate_files/reads_vs_IS.paf') as f:
    for line in f:
        fields = line.strip().split('\t')
        if fields[0] in reads_in_cluster:
            print(fields)
# Out:
# ['HISEQ:190:C6DEVANXX:3:1308:15587:72532/1', '99', '0', '67', '+', 'IS6110', '1355', '1288', '1355', '67', '67', '60', 'NM:i:0', 'ms:i:134', 'AS:i:134', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:67M']
# ['HISEQ:190:C6DEVANXX:3:1308:15587:72532/1', '99', '70', '99', '+', 'IS6110', '1355', '0', '29', '29', '29', '8', 'NM:i:0', 'ms:i:58', 'AS:i:58', 'nn:i:0', 'tp:A:P', 'cm:i:3', 's1:i:16', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:29M']
# ['HISEQ:190:C6DEVANXX:3:1310:10510:61932/1', '100', '0', '67', '+', 'IS6110', '1355', '1288', '1355', '67', '67', '60', 'NM:i:0', 'ms:i:134', 'AS:i:134', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:67M']
# ['HISEQ:190:C6DEVANXX:3:1310:10510:61932/1', '100', '70', '100', '+', 'IS6110', '1355', '0', '30', '30', '30', '8', 'NM:i:0', 'ms:i:60', 'AS:i:60', 'nn:i:0', 'tp:A:P', 'cm:i:3', 's1:i:16', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:30M']
# ['HISEQ:190:C6DEVANXX:3:2313:11577:56058/2', '100', '37', '100', '-', 'IS6110', '1355', '1292', '1355', '63', '63', '60', 'NM:i:0', 'ms:i:126', 'AS:i:126', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:63M']
# ['HISEQ:190:C6DEVANXX:3:2313:11577:56058/2', '100', '0', '34', '-', 'IS6110', '1355', '0', '34', '34', '34', '21', 'NM:i:0', 'ms:i:68', 'AS:i:68', 'nn:i:0', 'tp:A:P', 'cm:i:4', 's1:i:25', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:34M']
# ['HISEQ:190:C6DEVANXX:3:1212:10052:52138/2', '100', '0', '60', '+', 'IS6110', '1355', '1295', '1355', '60', '60', '60', 'NM:i:0', 'ms:i:120', 'AS:i:120', 'nn:i:0', 'tp:A:P', 'cm:i:9', 's1:i:50', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:60M']
# ['HISEQ:190:C6DEVANXX:3:1212:10052:52138/2', '100', '63', '100', '+', 'IS6110', '1355', '0', '37', '37', '37', '21', 'NM:i:0', 'ms:i:74', 'AS:i:74', 'nn:i:0', 'tp:A:P', 'cm:i:4', 's1:i:25', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:37M']
# ['HISEQ:190:C6DEVANXX:3:2206:5028:22644/2', '100', '0', '59', '+', 'IS6110', '1355', '1296', '1355', '59', '59', '60', 'NM:i:0', 'ms:i:118', 'AS:i:118', 'nn:i:0', 'tp:A:P', 'cm:i:9', 's1:i:50', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:59M']
# ['HISEQ:190:C6DEVANXX:3:2206:5028:22644/2', '100', '62', '100', '+', 'IS6110', '1355', '0', '38', '38', '38', '21', 'NM:i:0', 'ms:i:76', 'AS:i:76', 'nn:i:0', 'tp:A:P', 'cm:i:4', 's1:i:25', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:38M']
# ['HISEQ:190:C6DEVANXX:3:1314:9307:62861', '185', '62', '185', '-', 'IS6110', '1355', '1232', '1355', '123', '123', '60', 'NM:i:0', 'ms:i:246', 'AS:i:246', 'nn:i:0', 'tp:A:P', 'cm:i:20', 's1:i:117', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:123M']
# ['HISEQ:190:C6DEVANXX:3:1314:9307:62861', '185', '0', '59', '-', 'IS6110', '1355', '0', '59', '59', '59', '60', 'NM:i:0', 'ms:i:118', 'AS:i:118', 'nn:i:0', 'tp:A:P', 'cm:i:7', 's1:i:47', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:59M']
# ['HISEQ:190:C6DEVANXX:3:1114:3191:45226/2', '100', '29', '100', '-', 'IS6110', '1355', '1284', '1355', '71', '71', '60', 'NM:i:0', 'ms:i:142', 'AS:i:142', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:71M']
# ['HISEQ:190:C6DEVANXX:3:1114:3191:45226/2', '100', '0', '26', '-', 'IS6110', '1355', '0', '26', '26', '26', '2', 'NM:i:0', 'ms:i:52', 'AS:i:52', 'nn:i:0', 'tp:A:P', 'cm:i:2', 's1:i:12', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:26M']
# ['HISEQ:190:C6DEVANXX:3:2316:18675:31026/1', '100', '29', '100', '-', 'IS6110', '1355', '1284', '1355', '71', '71', '60', 'NM:i:0', 'ms:i:142', 'AS:i:142', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:71M']
# ['HISEQ:190:C6DEVANXX:3:2316:18675:31026/1', '100', '0', '26', '-', 'IS6110', '1355', '0', '26', '26', '26', '2', 'NM:i:0', 'ms:i:52', 'AS:i:52', 'nn:i:0', 'tp:A:P', 'cm:i:2', 's1:i:12', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:26M']
# ['HISEQ:190:C6DEVANXX:3:2310:2539:83965/1', '100', '0', '69', '+', 'IS6110', '1355', '1286', '1355', '69', '69', '60', 'NM:i:0', 'ms:i:138', 'AS:i:138', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:69M']
# ['HISEQ:190:C6DEVANXX:3:2310:2539:83965/1', '100', '72', '100', '+', 'IS6110', '1355', '0', '28', '28', '28', '2', 'NM:i:0', 'ms:i:56', 'AS:i:56', 'nn:i:0', 'tp:A:P', 'cm:i:2', 's1:i:12', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:28M']
# ['HISEQ:190:C6DEVANXX:3:1102:20362:51281/1', '100', '0', '67', '+', 'IS6110', '1355', '1288', '1355', '67', '67', '60', 'NM:i:0', 'ms:i:134', 'AS:i:134', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:67M']
# ['HISEQ:190:C6DEVANXX:3:1102:20362:51281/1', '100', '70', '100', '+', 'IS6110', '1355', '0', '30', '30', '30', '8', 'NM:i:0', 'ms:i:60', 'AS:i:60', 'nn:i:0', 'tp:A:P', 'cm:i:3', 's1:i:16', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:30M']
# ['HISEQ:190:C6DEVANXX:3:1114:11138:15237/2', '100', '35', '100', '-', 'IS6110', '1355', '1290', '1355', '65', '65', '60', 'NM:i:0', 'ms:i:130', 'AS:i:130', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:65M']
# ['HISEQ:190:C6DEVANXX:3:1114:11138:15237/2', '100', '0', '32', '-', 'IS6110', '1355', '0', '32', '32', '32', '20', 'NM:i:0', 'ms:i:64', 'AS:i:64', 'nn:i:0', 'tp:A:P', 'cm:i:4', 's1:i:25', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:32M']
# ['HISEQ:190:C6DEVANXX:3:1208:10099:87731/1', '100', '0', '64', '+', 'IS6110', '1355', '1291', '1355', '64', '64', '60', 'NM:i:0', 'ms:i:128', 'AS:i:128', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:64M']
# ['HISEQ:190:C6DEVANXX:3:1208:10099:87731/1', '100', '67', '100', '+', 'IS6110', '1355', '0', '33', '33', '33', '20', 'NM:i:0', 'ms:i:66', 'AS:i:66', 'nn:i:0', 'tp:A:P', 'cm:i:4', 's1:i:25', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:33M']
# ['HISEQ:190:C6DEVANXX:3:2202:20114:52559/2', '98', '0', '64', '+', 'IS6110', '1355', '1291', '1355', '64', '64', '60', 'NM:i:0', 'ms:i:128', 'AS:i:128', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:64M']
# ['HISEQ:190:C6DEVANXX:3:2202:20114:52559/2', '98', '67', '98', '+', 'IS6110', '1355', '0', '31', '31', '31', '8', 'NM:i:0', 'ms:i:62', 'AS:i:62', 'nn:i:0', 'tp:A:P', 'cm:i:3', 's1:i:16', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:31M']
# ['HISEQ:190:C6DEVANXX:3:2311:19172:83353/2', '100', '22', '100', '+', 'IS6110', '1355', '0', '78', '77', '78', '60', 'NM:i:1', 'ms:i:146', 'AS:i:146', 'nn:i:0', 'tp:A:P', 'cm:i:8', 's1:i:54', 's2:i:0', 'de:f:0.0128', 'rl:i:0', 'cg:Z:78M']
# ['HISEQ:190:C6DEVANXX:3:2115:15540:74418/1', '100', '0', '71', '+', 'IS6110', '1355', '1284', '1355', '71', '71', '60', 'NM:i:0', 'ms:i:142', 'AS:i:142', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:71M']
# ['HISEQ:190:C6DEVANXX:3:2115:15540:74418/1', '100', '74', '100', '+', 'IS6110', '1355', '0', '26', '26', '26', '2', 'NM:i:0', 'ms:i:52', 'AS:i:52', 'nn:i:0', 'tp:A:P', 'cm:i:2', 's1:i:12', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:26M']
# ['HISEQ:190:C6DEVANXX:3:2308:1320:74215/2', '100', '0', '79', '-', 'IS6110', '1355', '0', '79', '79', '79', '60', 'NM:i:0', 'ms:i:158', 'AS:i:158', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:67', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:79M']
# ['HISEQ:190:C6DEVANXX:3:2301:17640:65285', '174', '0', '115', '+', 'IS6110', '1355', '1240', '1355', '115', '115', '60', 'NM:i:0', 'ms:i:230', 'AS:i:230', 'nn:i:0', 'tp:A:P', 'cm:i:18', 's1:i:110', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:115M']
# ['HISEQ:190:C6DEVANXX:3:2301:17640:65285', '174', '118', '174', '+', 'IS6110', '1355', '0', '56', '56', '56', '45', 'NM:i:0', 'ms:i:112', 'AS:i:112', 'nn:i:0', 'tp:A:P', 'cm:i:6', 's1:i:38', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:56M']
# ['HISEQ:190:C6DEVANXX:3:1107:5967:77221', '168', '77', '168', '-', 'IS6110', '1355', '1264', '1355', '91', '91', '60', 'NM:i:0', 'ms:i:182', 'AS:i:182', 'nn:i:0', 'tp:A:P', 'cm:i:14', 's1:i:85', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:91M']
# ['HISEQ:190:C6DEVANXX:3:1107:5967:77221', '168', '0', '74', '-', 'IS6110', '1355', '0', '74', '74', '74', '60', 'NM:i:0', 'ms:i:148', 'AS:i:148', 'nn:i:0', 'tp:A:P', 'cm:i:9', 's1:i:62', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:74M']
# ['HISEQ:190:C6DEVANXX:3:1211:4973:67209/1', '100', '29', '100', '-', 'IS6110', '1355', '1284', '1355', '71', '71', '60', 'NM:i:0', 'ms:i:142', 'AS:i:142', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:71M']
# ['HISEQ:190:C6DEVANXX:3:1211:4973:67209/1', '100', '0', '26', '-', 'IS6110', '1355', '0', '26', '26', '26', '2', 'NM:i:0', 'ms:i:52', 'AS:i:52', 'nn:i:0', 'tp:A:P', 'cm:i:2', 's1:i:12', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:26M']
# ['HISEQ:190:C6DEVANXX:3:1314:20039:60270/1', '100', '29', '100', '-', 'IS6110', '1355', '1284', '1355', '71', '71', '60', 'NM:i:0', 'ms:i:142', 'AS:i:142', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:71M']
# ['HISEQ:190:C6DEVANXX:3:1314:20039:60270/1', '100', '0', '26', '-', 'IS6110', '1355', '0', '26', '26', '26', '2', 'NM:i:0', 'ms:i:52', 'AS:i:52', 'nn:i:0', 'tp:A:P', 'cm:i:2', 's1:i:12', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:26M']
# ['HISEQ:190:C6DEVANXX:3:2111:10069:4452/1', '100', '32', '100', '-', 'IS6110', '1355', '1287', '1355', '68', '68', '60', 'NM:i:0', 'ms:i:136', 'AS:i:136', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:68M']
# ['HISEQ:190:C6DEVANXX:3:2111:10069:4452/1', '100', '0', '29', '-', 'IS6110', '1355', '0', '29', '29', '29', '8', 'NM:i:0', 'ms:i:58', 'AS:i:58', 'nn:i:0', 'tp:A:P', 'cm:i:3', 's1:i:16', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:29M']
# ['HISEQ:190:C6DEVANXX:3:2101:16373:97258/2', '100', '37', '100', '-', 'IS6110', '1355', '1292', '1355', '63', '63', '60', 'NM:i:0', 'ms:i:126', 'AS:i:126', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:63M']
# ['HISEQ:190:C6DEVANXX:3:2101:16373:97258/2', '100', '0', '34', '-', 'IS6110', '1355', '0', '34', '34', '34', '21', 'NM:i:0', 'ms:i:68', 'AS:i:68', 'nn:i:0', 'tp:A:P', 'cm:i:4', 's1:i:25', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:34M']
# ['HISEQ:190:C6DEVANXX:3:2112:18264:8071/1', '100', '37', '100', '-', 'IS6110', '1355', '1292', '1355', '63', '63', '60', 'NM:i:0', 'ms:i:126', 'AS:i:126', 'nn:i:0', 'tp:A:P', 'cm:i:10', 's1:i:59', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:63M']
# ['HISEQ:190:C6DEVANXX:3:2112:18264:8071/1', '100', '0', '34', '-', 'IS6110', '1355', '0', '34', '34', '34', '21', 'NM:i:0', 'ms:i:68', 'AS:i:68', 'nn:i:0', 'tp:A:P', 'cm:i:4', 's1:i:25', 's2:i:0', 'de:f:0', 'rl:i:0', 'cg:Z:34M']

# %% [markdown]
# ## Wrong anchor sequences?
#
# Check out anchors at CRISPR locus.
#
# '/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/art_reads/ASM93432v3.COV40.RL100.1.fq.gz'
# '/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/art_reads/ASM93432v3.COV40.RL100.2.fq.gz'

# %% [markdown]
# # Sensitivity
#
# Samples with decline in sensitivity at higher coverage.
#
# Copy identified:
#
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM515610v1/COV30.RL100.1.fq.gz"
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM515610v1/COV30.RL100.2.fq.gz"
#
# Copy missing 5' anchor:
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM515610v1/COV50.RL100.1.fq.gz"
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM515610v1/COV50.RL100.2.fq.gz"
#
#
# Sample with consistently poor sensitivity:
#
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM25337v1/COV30.RL100.1.fq.gz"
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM25337v1/COV30.RL100.2.fq.gz"

# %% [markdown]
# # Precision
#
# Issue with fals positives arising from degraded/poorly assembled copies with recognizable IRs.
#
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM73844v1/COV50.RL100.1.fq.gz"
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM73844v1/COV50.RL100.2.fq.gz"
#
# -> high entropy for anchors and targets!

# %% [markdown]
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM25337v1/COV50.RL100.1.fq.gz",
# "/scicore/home/gagneux/stritt0001/TB/projects/MTBC_IS6110-poly/workflow/results/mtbc1175_2/benchmarking/art_reads/ASM25337v1/COV50.RL100.2.fq.gz"
